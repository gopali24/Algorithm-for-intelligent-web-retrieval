# %% [markdown]
# # Week 1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import numpy as np
import os
from nltk.stem import PorterStemmer
from natsort import natsorted 
import string
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
#nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet')
import copy
from functools import reduce

# %%
df = pd.read_csv("stockerbot-export1.csv")
df=df[['text']]
df['text'] = df['text'].astype(str)
df.head()
# Out:
#                                                 text
# 0  VIDEO: “I was in my office. I was minding my o...
# 1  The price of lumber $LB_F is down 22% since hi...
# 2  Who says the American Dream is dead? https://t...
# 3  Barry Silbert is extremely optimistic on bitco...
# 4  How satellites avoid attacks and space junk wh...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28440 entries, 0 to 28439
# Data columns (total 1 columns):
# text    28440 non-null object
# dtypes: object(1)
# memory usage: 222.3+ KB

# %% [markdown]
# # Tokenization using RegexpTokenizer

# %%
df['text'] = df['text'].replace(r'http\S+','',regex=True).replace(r'www\S+','',regex=True)
df.head()
# Out:
#                                                 text
# 0  VIDEO: “I was in my office. I was minding my o...
# 1  The price of lumber $LB_F is down 22% since hi...
# 2              Who says the American Dream is dead?
# 3  Barry Silbert is extremely optimistic on bitco...
# 4  How satellites avoid attacks and space junk wh...

# %%
tokens = RegexpTokenizer(r'\w+')
df['text']=df['text'].apply(lambda x:tokens.tokenize(x.lower()))
df.head()
# Out:
#                                                 text
# 0  [video, i, was, in, my, office, i, was, mindin...
# 1  [the, price, of, lumber, lb_f, is, down, 22, s...
# 2        [who, says, the, american, dream, is, dead]
# 3  [barry, silbert, is, extremely, optimistic, on...
# 4  [how, satellites, avoid, attacks, and, space, ...

# %% [markdown]
# ## Removing stop words

# %%
stop_words = set(stopwords.words('english')) 
stop_words = stop_words.union(",","(",")","[","]","{","}","#","@","!",":",";",".","?")
df['text'] = df['text'].apply(lambda x: [item for item in x if item not in stop_words])
df.head()
# Out:
#                                                 text
# 0  [video, office, minding, business, david, solo...
# 1  [price, lumber, lb_f, 22, since, hitting, ytd,...
# 2                      [says, american, dream, dead]
# 3  [barry, silbert, extremely, optimistic, bitcoi...
# 4  [satellites, avoid, attacks, space, junk, circ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28440 entries, 0 to 28439
# Data columns (total 1 columns):
# text    28440 non-null object
# dtypes: object(1)
# memory usage: 222.3+ KB

# %% [markdown]
# ---
#
# # Week 2
#
# ---

# %% [markdown]
# # Lemmetization using WordNetLemmatizer

# %%
lem = WordNetLemmatizer()
def lemm(text):
    sent=[]
    for word in text:
        sent.append(lem.lemmatize(word))
    return sent

# %% [markdown]
# # Stemming using PorterStemmer

# %%
ps=PorterStemmer()

def stemm(text):        
    sent = []
    for word in text:
        sent.append(ps.stem(word))
    return sent

# %%
df["text_final"] =  df.apply(lambda x: stemm(lemm(x['text'])), axis=1)

# %%
df.head()
# Out:
#                                                 text  \
# 0  [video, office, minding, business, david, solo...
# 1  [price, lumber, lb_f, 22, since, hitting, ytd,...
# 2                      [says, american, dream, dead]
# 3  [barry, silbert, extremely, optimistic, bitcoi...
# 4  [satellites, avoid, attacks, space, junk, circ...
#
#                                           text_final
# 0  [video, offic, mind, busi, david, solomon, tel...
# 1  [price, lumber, lb_f, 22, sinc, hit, ytd, high...
# 2                       [say, american, dream, dead]
# 3  [barri, silbert, extrem, optimist, bitcoin, pr...
# 4  [satellit, avoid, attack, space, junk, circl, ...

# %% [markdown]
# ---
# # Creating postings list for inverted index

# %%
inv_ind={}
cnt=1
for i in df['text_final']:
    for item in i:
        if item not in inv_ind:
            inv_ind[item]=[]
        if cnt not in inv_ind[item]:
            inv_ind[item].append(cnt)
    cnt+=1
print(inv_ind)
# Out:
# {'video': [1, 801, 1049, 1207, 1328, 1448, 1589, 1598, 1777, 1871, 1925, 2119, 2356, 2440, 2553, 2704, 2705, 3419, 3420, 3598, 3605, 3625, 3627, 3684, 4542, 4551, 5187, 5491, 5509, 5619, 5671, 5779, 5865, 6149, 6674, 6749, 6806, 8143, 8210, 8375, 8387, 8388, 8389, 8390, 8391, 8392, 8393, 8394, 8396, 8397, 8398, 8399, 8400, 8401, 8412, 8487, 8490, 8852, 8891, 8894, 8895, 8916, 10501, 10655, 10665, 10680, 11806, 11826, 12020, 12051, 12222, 12304, 13655, 14541, 14937, 15079, 15328, 15692, 16198, 16239, 16529, 16599, 17439, 17995, 18145, 18686, 18909, 19091, 19350, 19534, 20101, 20209, 20324, 20945, 21008, 22185, 22605, 22613, 22624, 22700, 22702, 22757, 22770, 23409, 23426, 23470, 23560, 24075, 24150, 24349, 24695, 24723, 24888, 24936, 25452, 25763, 25855, 25860, 26091, 26127, 26259, 26336, 26349, 26379, 26485, 26595, 26676, 26685, 27113, 27137, 27704, 27866, 28114, 28187, 28387], 'offic': [1, 340, 343, 653, 838, 839, 1261, 1266, 1923, 1924, 1979, 2035, 2038, 2990, 3229, 3360, 3526, 3838, 3977, 4570, 4686, 4911, 5199, 5314, 5321, 5379, 5615, 5633, 6641, 6646, 6762, 6775, 6779, 7183, 7251, 7294, 7391, 8693, 8694, 9620, 9627, 9643, 9680, 10226, 11744, 11992, 12172, 12251, 12280, 12286, 14823, 15109, 15129, 15742, 15839, 16203, 16273, 16446, 16503, 16611, 16641, 16642, 19983, 20548, 20934, 20946, 22671, 24784, 24815, 24946, 25725, 25962, 26254, 26335, 26386, 26427, 26432, 27525, 27528], 'mind': [1, 1663, 10126, 10301, 12465, 14346, 15670, 15680, 15903, 16182, 17493, 17563, 20156, 21308, 23121, 26623, 26649, 26881, 27460, 27576, 27847, 27979, 28263], 'busi': [1, 986, 1128, 2538, 3635, 3902, 4954, 5836, 6075, 6730, 8969, 8971, 9628, 10164, 10738, 11023, 11187, 12351, 12361, 12420, 13781, 13986, 14014, 14243, 14933, 14949, 15164, 15794, 16335, 16418, 17309, 18138, 19954, 19999, 20071, 20129, 20144, 20145, 20544, 20610, 21225, 21250, 21599, 21613, 21615, 21620, 21754, 22058, 22142, 22574, 22766, 22792, 22818, 22835, 22855, 22857, 22859, 22861, 22881, 22895, 23024, 23034, 23128, 23612, 23680, 23704, 23743, 23756, 24012, 24141, 24484, 24506, 24863, 25003, 25004, 25174, 26526, 26549, 26552, 26555, 26573, 26591, 26604, 26621, 26671, 26727, 26846, 26853, 26862, 26988, 26990, 27030, 27049, 27061, 27083, 27147, 27209, 27268, 27291, 27296, 27408, 27419, 27508, 27525, 27528, 27623, 27627, 27679, 27723, 27831, 27882, 27904, 28236, 28378, 28409], 'david': [1, 6, 4017, 4040, 4413, 5318, 5495, 6611, 6904, 7303, 7319, 11244, 12489, 13027, 13096, 15369, 15573, 15993, 16078, 16431, 16446, 16723, 16828, 17922, 18311, 19052, 19071, 23748, 24618, 26254, 26499, 26783, 26784, 27872, 28228], 'solomon': [1], 'tell': [1, 21, 1483, 2781, 5435, 8545, 8548, 9328, 9356, 9615, 10161, 11091, 12098, 15810, 17543, 17731, 17825, 21085, 21574, 22144, 22948, 22961, 23738, 25399, 25516, 25601, 25631, 25657, 25861, 26246, 26404, 26434, 26581, 26802, 26852, 26952, 27207, 28417], 'g': [1, 259, 273, 396, 420, 541, 674, 1069, 1420, 2002, 2053, 2081, 2220, 3033, 3439, 3820, 3821, 3968, 3971, 4450, 5069, 5393, 5443, 5925, 5945, 5956, 5961, 5962, 5966, 5967, 5983, 5984, 5988, 5990, 6016, 6022, 6026, 6031, 6048, 6057, 6061, 6062, 6063, 6064, 6065, 6116, 6128, 6132, 6147, 6157, 6171, 6184, 6213, 6252, 6446, 6466, 6554, 6555, 6557, 6560, 6561, 6564, 6568, 6582, 6584, 6588, 6592, 6696, 6736, 6953, 6989, 7061, 7239, 7275, 7392, 7788, 8008, 8658, 8662, 8682, 8760, 8765, 8769, 8774, 8775, 8787, 8788, 8790, 8806, 8817, 8824, 8825, 8833, 8843, 8850, 8863, 8902, 8906, 8915, 8922, 8932, 8936, 8943, 8951, 8962, 8974, 8998, 9004, 9005, 9009, 9019, 9072, 9151, 9229, 9232, 9457, 9458, 9576, 9586, 9610, 9642, 9672, 9687, 9688, 9693, 9695, 9708, 9716, 9717, 9723, 9731, 9751, 9752, 9761, 9777, 9807, 9833, 9875, 9966, 10160, 10230, 10248, 10380, 10388, 10403, 10487, 10548, 10598, 10700, 10774, 10784, 10828, 10870, 10872, 10948, 11044, 11132, 11209, 11248, 11265, 11487, 11538, 11553, 11606, 11607, 11667, 11676, 11693, 11738, 11785, 11832, 11900, 11921, 11922, 11931, 11945, 12079, 12095, 12124, 12172 ...

# %%
def find(word):
    print(inv_ind[word])
find("crypto")
# Out:
# [4, 3377, 4222, 5302, 8544, 11868, 12908, 12964, 13028, 13170, 13240, 13300, 13509, 13559, 13618, 13680, 13794, 14012, 14047, 14173, 14325, 14422, 14556, 14648, 14725, 14882, 14932, 14983, 14986, 15086, 15178, 15350, 15352, 15354, 15360, 15387, 15415, 15417, 15509, 15543, 15555, 15597, 15726, 15820, 15951, 15958, 15960, 16142, 16159, 16199, 16218, 16265, 16278, 16285, 16334, 16361, 16382, 16497, 16544, 16556, 16586, 16587, 16661, 16719, 16722, 16742, 16772, 16776, 16899, 16905, 16951, 16973, 17061, 17109, 17115, 17116, 17133, 17160, 17172, 17175, 17205, 17207, 17235, 17297, 17307, 17345, 17352, 17361, 17365, 17366, 17427, 17428, 17432, 17503, 17511, 17531, 17539, 17547, 17573, 17605, 17612, 17619, 17636, 17673, 17684, 17694, 17696, 17701, 17721, 17728, 17766, 17780, 17791, 17813, 17817, 17835, 17837, 17871, 17919, 17935, 17965, 17972, 17986, 17993, 17999, 18007, 18025, 18027, 18059, 18070, 18079, 18081, 18115, 18151, 18163, 18164, 18198, 18207, 18210, 18253, 18256, 18288, 18303, 18307, 18328, 18337, 18357, 18383, 18426, 18432, 18444, 18452, 18471, 18478, 18485, 18504, 18550, 18560, 18603, 18610, 18642, 18678, 18685, 18730, 18732, 18742, 18773, 18801, 18824, 18835, 18856, 18861, 18863, 18868, 18888, 18908, 18929, 18934, 19059, 19061, 19087, 19094, 19116, 19123, 19134, 19142, 19168, 19170, 19244, 19344, 19433, 19502, 19507, 19659, 19690, 19695, 19705, 19785, 19793, 19907, 19960, 20063, 20265, 20274, 20346, 20446, 20449, 20458, 20479, 20508, 20509, 20522, 20597, 20716, 20765, 20848, 20893, 21042, 21136, 21202, 21206, 21385, 21461, 21474, 21514, 21547, 21681, 21702, 21765, 21792, 21902, 21964, 21970, 22078, 22109, 22126, 22179, 22186, 22187, 22235, 22252, 22281, 22308, 22346, 22363, 22390, 22486, 22489, 22561, 22564, 22579, 22642, 22665, 22734, 22744, 22752, 22763, 22880, 22911, 22998, 23036, 23088, 23150, 23184, 23240, 23270, 23337, 23346, 23352, 23360, 23361, 23366, 23371, 23407, 23421, 23427, 23530, 23542, 23566, 23572, 23603, 23650, 23745, 23747, 23779, 23835, 23850, 23937, 23967, 24053, 24114, 24153, 24208, 24350, 24374, 24415, 24417, 24424, 24528, 24610, 24623, 24626, 24655, 24667, 24690, 24709, 24753, 24759, 24761, 24765, 24773, 24844, 24856, 24869, 24889, 24941, 24965, 24972, 24980, 24985, 25130, 25175, 25185, 25230, 25306, 25498, 25529, 25541, 25587, 25643, 25651, 25674, 25685, 25688, 25696, 25757, 25758, 25761, 25769, 25781, 25811, 25812, 25815, 25821, 25846, 25886, 25953, 25957, 26081, 26082, 26095, 26102, 26107, 26108, 26117, 26121, 26147, 26156, 26199, 26213, 26218, 26222, 26236, 26252, 26255, 26263, 26382, 26464, 26508, 26626, 26640, 26664, 26706, 26739, 26763, 26815, 26818, 26870, 26873, 26889, 26892, 26999, 27042, 27055, 27060, 27076, 27090, 27108, 27112, 27272, 27273, 27324, 27368, 27414, 27481, 27491, 27517, 27600, 27614, 27617, 27640, 27702, 27705, 27727, 27732, 27747, 27760, 27778, 27807, 27828, 27840, 27900, 27910, 27914, 27959, 27960, 27987, 28005, 28025, 28135, 28141, 28160, 28200, 28221, 28233, 28272, 28293, 28307, 28310, 28332, 28365, 28368, 28369, 28391, 28407, 28435, 28438]
